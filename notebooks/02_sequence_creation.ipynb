# %% [markdown]
# <a href="https://colab.research.google.com/github/SIDDH4RTH245/lstm-time-series-forecasting/blob/main/notebooks/02_sequence_creation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Step 2: Create Sequences

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("/content/airline-passengers.csv")

df.columns = ["Month", "Passengers"]

from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
data = scaler.fit_transform(df[["Passengers"]])

# %%
def create_sequences(data, seq_length=10):
    X = []
    y = []

    for i in range(len(data)-seq_length):
        X.append(data[i:i+seq_length])
        y.append(data[i+seq_length])

    return np.array(X), np.array(y)

X, y = create_sequences(data)
